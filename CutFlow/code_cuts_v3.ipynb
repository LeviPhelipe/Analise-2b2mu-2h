# %%
import pyhepmc as hep
import pandas as pd
import fastjet as fj
import numpy as np
import os
import gc
import psutil  # Para medir memória

# Limite de eventos e chunk
max_events = 1000000
chunk_size = 500

# Diretório de saída
output_dir = "resultados_csv"
os.makedirs(output_dir, exist_ok=True)

# Arquivos de sinal e background
sinal_files = [f'/home/lphelipe/Resultados/v3/pp_hh_{i}.hepmc' for i in range(1, 11)]
background_files = [
    '/home/lphelipe/Resultados/v3/pp_zz_1.hepmc',
    '/home/lphelipe/Resultados/v3/pp_zz_2.hepmc',
    '/home/lphelipe/Resultados/v3/pp_zz_3.hepmc',
    '/home/lphelipe/Resultados/v3/pp_zz_4.hepmc',
    '/home/lphelipe/Resultados/v3/pp_zz_5.hepmc',
    '/home/lphelipe/Resultados/v3/pp_zz_6.hepmc',
    '/home/lphelipe/Resultados/v3/pp_zz_7.hepmc',
    '/home/lphelipe/Resultados/v3/pp_zz_8.hepmc',
    '/home/lphelipe/Resultados/v3/pp_zz_9.hepmc',
    '/home/lphelipe/Resultados/v3/pp_zz_10.hepmc',
    '/home/lphelipe/Resultados/v3/pp_hjj_2mu.hepmc',
    '/home/lphelipe/Resultados/v3/pp_jj.hepmc',
    '/home/lphelipe/Resultados/v3/pp_jjmumu.hepmc',
    '/home/lphelipe/Resultados/v3/pp_tt.hepmc',
    '/home/lphelipe/Resultados/v3/pp_zjj_2b.hepmc',
    '/home/lphelipe/Resultados/v3/pp_zjj_2mu.hepmc'
]

# ---------------- Funções básicas ----------------
def memory_usage_gb():
    process = psutil.Process(os.getpid())
    mem_bytes = process.memory_info().rss
    return mem_bytes / 1e9  # Convertendo para GB

def remove_muons(particles):
    return [p for p in particles if abs(p.pid) != 13]

def find_opposite_charge_muons(particles):
    muons = [p for p in particles if abs(p.pid) == 13 and p.momentum.pt() > 20.0 and abs(p.momentum.eta()) < 2.5]
    muons_sorted = sorted(muons, key=lambda m: m.momentum.pt(), reverse=True)
    pairs = []
    used_indices = set()
    for i in range(len(muons_sorted)):
        if i in used_indices:
            continue
        for j in range(i+1, len(muons_sorted)):
            if j in used_indices:
                continue
            if muons_sorted[i].pid == -muons_sorted[j].pid:
                pairs.append((muons_sorted[i], muons_sorted[j]))
                used_indices.add(i)
                used_indices.add(j)
                break
    return pairs

def invariant_mass(jet1, jet2):
    E_tot = jet1.e() + jet2.e()
    px_tot = jet1.px() + jet2.px()
    py_tot = jet1.py() + jet2.py()
    pz_tot = jet1.pz() + jet2.pz()
    return np.sqrt(E_tot**2 - (px_tot**2 + py_tot**2 + pz_tot**2))

def delta_r(jet1, jet2):
    dphi = jet1.phi() - jet2.phi()
    deta = jet1.eta() - jet2.eta()
    return np.sqrt(dphi**2 + deta**2)

def is_b_tagged(jet, particles, cone_radius=0.4):
    secondary_vertex_displacement = []
    for p in particles:
        if p.production_vertex is not None:
            r_prod = np.sqrt(p.production_vertex.position.x**2 + p.production_vertex.position.y**2)
            secondary_vertex_displacement.append(r_prod)
    if len(secondary_vertex_displacement) > 0:
        mean_displacement = np.mean(secondary_vertex_displacement)
        return mean_displacement > 1.0, mean_displacement
    return False, 0.0

def read_hepmc_file_in_chunks(hepmc_file):
    events = []
    with hep.open(hepmc_file) as f:
        for i, event in enumerate(f):
            if i >= max_events:
                break
            if event is None:
                continue
            events.append(event)
            if (i+1) % chunk_size == 0:
                print(f"{i+1} eventos lidos do arquivo {os.path.basename(hepmc_file)} / mem: {memory_usage_gb():.2f} Gb")
                yield events
                events = []
                gc.collect()
        if events:
            print(f"{i+1} eventos lidos do arquivo {os.path.basename(hepmc_file)} (último chunk) / mem: {memory_usage_gb():.2f} Gb")
            yield events

def extract_event_info(events, weights=None):
    data = []
    for i, event in enumerate(events):
        particles = [p for p in event.particles if p.status == 1 and p.momentum.pt() > 2.0]
        muon_pairs = find_opposite_charge_muons(particles)
        if not muon_pairs:
            continue
        mu1, mu2 = muon_pairs[0]
        muon1 = fj.PseudoJet(mu1.momentum.x, mu1.momentum.y, mu1.momentum.z, mu1.momentum.e)
        muon2 = fj.PseudoJet(mu2.momentum.x, mu2.momentum.y, mu2.momentum.z, mu2.momentum.e)
        inv_mass_muons = invariant_mass(muon1, muon2)
        if not (100 < inv_mass_muons < 150):
            continue
        particles_no_muons = remove_muons(particles)
        fj_particles = [fj.PseudoJet(p.momentum.x, p.momentum.y, p.momentum.z, p.momentum.e) for p in particles_no_muons]
        jet_def = fj.JetDefinition(fj.antikt_algorithm, 0.4)
        clusterer = fj.ClusterSequence(fj_particles, jet_def)
        jets = [j for j in clusterer.inclusive_jets(30.0) if abs(j.eta()) < 4.5]
        jets_sorted = sorted(jets, key=lambda j: j.pt(), reverse=True)
        if len(jets_sorted) < 2:
            continue
        jet1, jet2 = jets_sorted[0], jets_sorted[1]
        dijet_mass = invariant_mass(jet1, jet2)
        if not (90 <= dijet_mass <= 160):
            continue
        is_b1, b_dist1 = is_b_tagged(jet1, particles_no_muons)
        is_b2, b_dist2 = is_b_tagged(jet2, particles_no_muons)

        di_muon_eta = 0.5*(muon1.eta() + muon2.eta())
        di_jet_eta = 0.5*(jet1.eta() + jet2.eta())
        di_b_eta = di_jet_eta
        di_muon_pt = muon1.pt() + muon2.pt()
        di_jet_b_pt = jet1.pt() + jet2.pt()
        di_muon_energy = muon1.e() + muon2.e()
        di_jet_b_energy = jet1.e() + jet2.e()
        jet1_b_pt = jet1.pt() if is_b1 else 0.0
        jet2_b_pt = jet2.pt() if is_b2 else 0.0

        event_info = {
            'muon_mass': inv_mass_muons,
            'muon1_pt': muon1.pt(),
            'muon2_pt': muon2.pt(),
            'muon1_eta': muon1.eta(),
            'muon2_eta': muon2.eta(),
            'dimuon_eta': di_muon_eta,
            'dimuon_pt': di_muon_pt,
            'dimuon_energy': di_muon_energy,
            'dijet_mass': dijet_mass,
            'jet1_pt': jet1.pt(),
            'jet2_pt': jet2.pt(),
            'jet1_eta': jet1.eta(),
            'jet2_eta': jet2.eta(),
            'di_jet_eta': di_jet_eta,
            'di_jet_pt': jet1.pt() + jet2.pt(),
            'di_jet_energy': jet1.e() + jet2.e(),
            'di_jet_b_pt': di_jet_b_pt,
            'di_jet_b_energy': di_jet_b_energy,
            'delta_r': delta_r(jet1, jet2),
            'num_jets': len(jets),
            'jet1_is_b_tagged': is_b1,
            'jet2_is_b_tagged': is_b2,
            'b_tag_distance1': b_dist1 if is_b1 else 0.0,
            'b_tag_distance2': b_dist2 if is_b2 else 0.0,
            'jet1_b_pt': jet1_b_pt,
            'jet2_b_pt': jet2_b_pt,
            'di_b_eta': di_b_eta,
            'weight_raw': weights[i] if weights is not None else 1.0
        }
        data.append(event_info)
    return pd.DataFrame(data)

def process_files(file_list, label):
    all_dfs = []
    for hepmc_file in file_list:
        processed_events = 0
        weights_raw = np.ones(max_events)
        for chunk in read_hepmc_file_in_chunks(hepmc_file):
            df_chunk = extract_event_info(chunk, weights_raw[processed_events:processed_events+len(chunk)])
            df_chunk['label'] = label
            all_dfs.append(df_chunk)
            processed_events += len(chunk)
    return pd.concat(all_dfs)

# ---------------- Processamento ----------------
signal_df = process_files(sinal_files, label=1)
signal_df.to_csv(os.path.join(output_dir, "signal_raw.csv"), index=False)

background_df = process_files(background_files, label=0)
background_df.to_csv(os.path.join(output_dir, "background_raw.csv"), index=False)

combined_df = pd.concat([signal_df, background_df])
combined_df.to_csv(os.path.join(output_dir, "all_events_raw.csv"), index=False)
# Out:
# 500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.37 Gb
# 1000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 1500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 2000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 2500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 3000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 3500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 4000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 4500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 5000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 5500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 6000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 6500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 7000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 7500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 8000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 8500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 9000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 9500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 10000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 10500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 11000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 11500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 12000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 12500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 13000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 13500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 14000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 14500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 15000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 15500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 16000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 16500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 17000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 17500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 18000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 18500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 19000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 19500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 20000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 20500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 21000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 21500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 22000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 22500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 23000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 23500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 24000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 24500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 25000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 25500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 26000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 26500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 27000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 27500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 28000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 28500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 29000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 29500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 30000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 30500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 31000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 31500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 32000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 32500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 33000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 33500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 34000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 34500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 35000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 35500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 36000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 36500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 37000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 37500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 38000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 38500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 39000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 39500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 40000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 40500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 41000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 41500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 42000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 42500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 43000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 43500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 44000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 44500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 45000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 45500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 46000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 46500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 47000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 47500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 48000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 48500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 49000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 49500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 50000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 50500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 51000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 51500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 52000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 52500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 53000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 53500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 54000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 54500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 55000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 55500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 56000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 56500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 57000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 57500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 58000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 58500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 59000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 59500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 60000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 60500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 61000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 61500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 62000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 62500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 63000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 63500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 64000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 64500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 65000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 65500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 66000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 66500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 67000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 67500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 68000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 68500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 69000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 69500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 70000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 70500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 71000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 71500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 72000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 72500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 73000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 73500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 74000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 74500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 75000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 75500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 76000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 76500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 77000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 77500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 78000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 78500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 79000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 79500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 80000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 80500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 81000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 81500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 82000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 82500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 83000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 83500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 84000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 84500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 85000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 85500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 86000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 86500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 87000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 87500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 88000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 88500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 89000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 89500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 90000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 90500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 91000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 91500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 92000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 92500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 93000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 93500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 94000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 94500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 95000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 95500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 96000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 96500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 97000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 97500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 98000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 98500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 99000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 99500 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 100000 eventos lidos do arquivo pp_hh_1.hepmc / mem: 3.36 Gb
# 500 eventos lidos do arquivo pp_hh_2.hepmc / mem: 3.36 Gb
# 1000 eventos lidos do arquivo pp_hh_2.hepmc / mem: 3.36 Gb
# 1500 eventos lidos do arquivo pp_hh_2.hepmc / mem: 3.36 Gb
# 2000 eventos lidos do arquivo pp_hh_2.hepmc / mem: 3.36 Gb
#
 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 699000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 699500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 700000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 700500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 701000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 701500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 702000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 702500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 703000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 703500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 704000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 704500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 705000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 705500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 706000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 706500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 707000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 707500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 708000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 708500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 709000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 709500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 710000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 710500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 711000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 711500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 712000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 712500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 713000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 713500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 714000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 714500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 715000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 715500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 716000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 716500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 717000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 717500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 718000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 718500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 719000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 719500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 720000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 720500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 721000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 721500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 722000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 722500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 723000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 723500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 724000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 724500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 725000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 725500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 726000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 726500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 727000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 727500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 728000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 728500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 729000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 729500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 730000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 730500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 731000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 731500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 732000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 732500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 733000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 733500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 734000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 734500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 735000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 735500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 736000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 736500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 737000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 737500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 738000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 738500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 739000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 739500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 740000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 740500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 741000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 741500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 742000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 742500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 743000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 743500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 744000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 744500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 745000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 745500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 746000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 746500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 747000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 747500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 748000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 748500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 749000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 749500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 750000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 750500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 751000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 751500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 752000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 752500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 753000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 753500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 754000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 754500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 755000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 755500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 756000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 756500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 757000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 757500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 758000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 758500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 759000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 759500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 760000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 760500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 761000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 761500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 762000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 762500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 763000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 763500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 764000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 764500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 765000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 765500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 766000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 766500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 767000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 767500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 768000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 768500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 769000 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb
# 769500 eventos lidos do arquivo pp_tt.hepmc / mem: 3.41 Gb

# %%
import pandas as pd
import numpy as np

# Luminosidade do FCC-hh [fb^-1]
TARGET_LUMINOSITY = 20000.0  # 20 ab^-1

# Função de normalização a partir do CSV
def normalize_weights_from_csv(df, weight_column='weight_raw', label_column='label', luminosity=TARGET_LUMINOSITY):
    """
    Normaliza os pesos do CSV usando a seção de choque de cada grupo (sinal/background)
    """
    df_norm = df.copy()
    df_norm['weight_norm'] = 0.0

    # Para cada categoria (label = 1 sinal, 0 background)
    for lbl in df[label_column].unique():
        sub_df = df[df[label_column] == lbl]
        weights = sub_df[weight_column].values
        
        # Aqui calculamos a seção de choque a partir do somatório dos pesos brutos
        # Para o CSV, assumimos que cross_section é proporcional à soma de pesos
        # Normalização total para a luminosidade alvo:
        sum_weights = np.sum(weights)
        if sum_weights == 0:
            norm_factor = 0
        else:
            # Fator de normalização: Σ(weight_norm) = L * σ_total
            # Como não temos σ por arquivo, podemos escalar para que a soma = 1e3 * L
            norm_factor = 1.0 * luminosity * 1e3 / sum_weights
        
        # Aplica a normalização
        df_norm.loc[df[label_column] == lbl, 'weight_norm'] = weights * norm_factor
        
        # Impressão de verificação
        print(f"Label={lbl}: Σpeso_normalizado={df_norm[df[label_column]==lbl]['weight_norm'].sum():.2f} (antes={sum_weights:.2f})")
    
    return df_norm

# Carrega o CSV
csv_file = "/home/lphelipe/Cuts_code/resultados_csv/all_events_raw.csv"
df_all = pd.read_csv(csv_file)

# Normaliza os pesos
df_all_norm = normalize_weights_from_csv(df_all)

# Salva em novo CSV
output_file = "all_events_normalized.csv"
df_all_norm.to_csv(output_file, index=False)
print(f"✅ CSV normalizado salvo em: {output_file}")
# Out:
# Label=1: Σpeso_normalizado=20000000.00 (antes=135114.00)
# Label=0: Σpeso_normalizado=20000000.00 (antes=41716.00)
# ✅ CSV normalizado salvo em: all_events_normalized.csv
